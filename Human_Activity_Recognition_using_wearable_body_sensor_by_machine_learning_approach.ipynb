# %% [markdown]
# <a href="https://colab.research.google.com/github/zahid-bracu/human-activity-recognition/blob/main/Human_Activity_Recognition_using_wearable_body_sensor_by_machine_learning_approach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Dataset from Git

# %%
# !git clone "https://github.com/laxmimerit/Human-Activity-Recognition-Using-Accelerometer-Data-and-CNN"
# Out:
# Cloning into 'Human-Activity-Recognition-Using-Accelerometer-Data-and-CNN'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 17 (delta 2), reused 9 (delta 1), pack-reused 0
# Unpacking objects: 100% (17/17), done.

# %%
# checking os paths

import os
path = os.listdir()[1]

# %%
path
# Out:
# 'Human-Activity-Recognition-Using-Accelerometer-Data-and-CNN'

# %%
os.listdir(path+'/WISDM_ar_v1.1')
# Out:
# ['WISDM_ar_v1.1_raw_about.txt',
#  'WISDM_ar_v1.1_raw.txt',
#  'readme.txt',
#  'WISDM_ar_v1.1_trans_about.txt',
#  'WISDM_ar_v1.1_transformed.arff']

# %% [markdown]
# # Data Preprocessing

# %%
# Loading dataset to a 'Processed List'

file = open(path + '/WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt')
lines = file.readlines()

processedList = []

for i, line in enumerate(lines):
    try:
        line = line.split(',')
        last = line[5].split(';')[0]
        last = last.strip()
        if last == '':
            break;
        temp = [line[0], line[1], line[2], line[3], line[4], last]
        processedList.append(temp)
    except:
        print('Error at line number: ', i)
# Out:
# Error at line number:  281873
# Error at line number:  281874
# Error at line number:  281875

# %% [markdown]
# # Loading Data Into Pandas DataFrame

# %%
# Create Pandas DataFrame from Processed List

import pandas as pd
columns = ['user', 'activity', 'time', 'x', 'y', 'z']
data = pd.DataFrame(data = processedList, columns = columns)
data.head()
# Out:
#   user activity            time            x          y            z
# 0   33  Jogging  49105962326000   -0.6946377  12.680544   0.50395286
# 1   33  Jogging  49106062271000     5.012288  11.264028   0.95342433
# 2   33  Jogging  49106112167000     4.903325  10.882658  -0.08172209
# 3   33  Jogging  49106222305000  -0.61291564  18.496431    3.0237172
# 4   33  Jogging  49106332290000   -1.1849703  12.108489     7.205164

# %%
data['activity'].value_counts()
# Out:
# Walking       137375
# Jogging       129392
# Upstairs       35137
# Downstairs     33358
# Sitting         4599
# Standing        3555
# Name: activity, dtype: int64

# %% [markdown]
# # Data type to Float

# %%
data['x'] = data['x'].astype('float')
data['y'] = data['y'].astype('float')
data['z'] = data['z'].astype('float')

# %% [markdown]
# # Time Series Visualization:

# %%
import matplotlib.pyplot as plt
import numpy as np

Fs = 20       # Sampling Frequency
activities = data['activity'].value_counts().index    # Activity names

# %%
# Helper functions for plotting activites

def plot_activity(activity, data):
    fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(15, 7), sharex=True)
    plot_axis(ax0, data['time'], data['x'], 'X-Axis')
    plot_axis(ax1, data['time'], data['y'], 'Y-Axis')
    plot_axis(ax2, data['time'], data['z'], 'Z-Axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(activity)
    plt.subplots_adjust(top=0.90)
    plt.show()

def plot_axis(ax, x, y, title):
    ax.plot(x, y, 'g')
    ax.set_title(title)
    ax.xaxis.set_visible(False)
    ax.set_ylim([min(y) - np.std(y), max(y) + np.std(y)])
    ax.set_xlim([min(x), max(x)])
    ax.grid(True)

for activity in activities:
    data_for_plot = data[(data['activity'] == activity)][:Fs*10]
    plot_activity(activity, data_for_plot)

# %% [markdown]
# ## Dropping User/Time axes

# %%
df = data.drop(['user', 'time'], axis = 1).copy()
df.head()
# Out:
#   activity         x          y         z
# 0  Jogging -0.694638  12.680544  0.503953
# 1  Jogging  5.012288  11.264028  0.953424
# 2  Jogging  4.903325  10.882658 -0.081722
# 3  Jogging -0.612916  18.496431  3.023717
# 4  Jogging -1.184970  12.108489  7.205164

# %% [markdown]
# # Balancing Data

# %%
# Taking the first 3555 samples from each class for balancing data

Walking = df[df['activity']=='Walking'].head(3555).copy()
Jogging = df[df['activity']=='Jogging'].head(3555).copy()
Upstairs = df[df['activity']=='Upstairs'].head(3555).copy()
Downstairs = df[df['activity']=='Downstairs'].head(3555).copy()
Sitting = df[df['activity']=='Sitting'].head(3555).copy()
Standing = df[df['activity']=='Standing'].copy()

# %%
# Creating balanced dataframe

balanced_data = pd.DataFrame()
balanced_data = balanced_data.append([Walking, Jogging, Upstairs, Downstairs, Sitting, Standing])
balanced_data.shape
# Out:
# (21330, 4)

# %%
balanced_data['activity'].value_counts()
# Out:
# Jogging       3555
# Downstairs    3555
# Upstairs      3555
# Standing      3555
# Walking       3555
# Sitting       3555
# Name: activity, dtype: int64

# %% [markdown]
# # Scaling Features

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = balanced_data[['x', 'y', 'z']]
y = balanced_data['activity']

# %%
# Using Scikit-learn's Standard Scalers to scale the input data

scaler = StandardScaler()
X = scaler.fit_transform(X)

scaled_X = pd.DataFrame(data = X, columns = ['x', 'y', 'z'])
scaled_X['label'] = y.values

scaled_X
# Out:
#               x         y         z     label
# 0      0.000503 -0.099190  0.337933   Walking
# 1      0.073590  0.020386  0.633446   Walking
# 2     -0.361275  1.588160 -0.103312   Walking
# 3      1.060258  0.437573 -0.844119   Walking
# 4     -0.237028  0.139962 -0.698386   Walking
# ...         ...       ...       ...       ...
# 21325 -0.470217  0.178084  0.261019  Standing
# 21326 -0.542658  0.193692  0.248875  Standing
# 21327 -0.628514  0.197593  0.261019  Standing
# 21328 -0.781444  0.049322  0.155768  Standing
# 21329 -0.800225  0.267827  0.475569  Standing
#
# [21330 rows x 4 columns]

# %% [markdown]
# # Creating Frames

# %%
import scipy.stats as stats
import numpy as np

# %%
Fs = 20            # Sampling Frequency
frame_size = Fs*4  # Taking the frame size of 80 (4  times Sampling Frequency)
hop_size = Fs*2    # Hop size of 40 between frames (2 times Sampling Freuquency)

# %%
# Helper function for getting frames

def get_frames(df, frame_size, hop_size):

    N_FEATURES = 3

    frames = []
    labels = []
    for i in range(0, len(df) - frame_size, hop_size):
        x = df['x'].values[i: i + frame_size]
        y = df['y'].values[i: i + frame_size]
        z = df['z'].values[i: i + frame_size]
        
        # Retrieve the most often used label in this segment
        label = stats.mode(df['label'][i: i + frame_size])[0][0]
        frames.append([x, y, z])
        labels.append(label)

    # Bring the segments into a better shape
    frames = np.asarray(frames).reshape(-1, frame_size, N_FEATURES)
    labels = np.asarray(labels)

    return frames, labels

# %%
X, Y = get_frames(scaled_X, frame_size, hop_size)

# %%
X.shape
# Out:
# (532, 80, 3)

# %%
x = X[:,:,0]
y = X[:,:,1]
z = X[:,:,2]

# %%
X.shape
# Out:
# (532, 80, 3)

# %%
x.shape
# Out:
# (532, 80)

# %% [markdown]
# # PCA Reduction : (532,80,3) -> (532,3,3)

# %%
from sklearn.decomposition import PCA

# Taking pca with 3 components along x,y,z axis seperately

pca = PCA(n_components = 3, random_state = 42)
pca_x = pca.fit_transform(x)
pca_y = pca.fit_transform(y)
pca_z = pca.fit_transform(z)

# %%
import numpy as np

# Stack pca results from different axes

pca_stack = np.stack((pca_x,pca_y,pca_z),axis = 2)
pca_stack.shape
# Out:
# (532, 3, 3)

# %%
pca_stack
# Out:
# array([[[-2.29397849, -1.70700462, -0.75965981],
#         [-1.56945586, -2.02519767, -1.08352346],
#         [-0.50483179, -0.16208085, -0.1238109 ]],
#
#        [[-0.38547113, -0.44126988, -1.96096916],
#         [-1.87982986, -1.48174349, -2.86045862],
#         [ 0.02428617, -0.25569758,  2.22927478]],
#
#        [[-0.61382428, -0.93136644, -0.2583071 ],
#         [-2.27581105, -4.19983346, -1.89657213],
#         [ 0.42543318,  2.28847072, -0.04490329]],
#
#        ...,
#
#        [[ 2.02169489,  2.02594519,  1.92994433],
#         [-2.56288012, -2.47899361, -2.49380132],
#         [ 0.84973403, -0.83223351, -0.79314975]],
#
#        [[ 1.95937953,  1.98532438,  1.85556628],
#         [-2.5516294 , -2.51935052, -2.51277074],
#         [ 0.86505628, -0.80416002, -0.75303145]],
#
#        [[ 2.01119544,  1.98968556,  1.88016282],
#         [-2.55298358, -2.48605449, -2.48853799],
#         [ 0.86794735, -0.82862713, -0.7959815 ]]])

# %% [markdown]
# # Plotting PCA

# %%
# !pip install plotly_express
# Out:
# Collecting plotly_express
#   Downloading https://files.pythonhosted.org/packages/d4/d6/8a2906f51e073a4be80cab35cfa10e7a34853e60f3ed5304ac470852a08d/plotly_express-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (0.5.1)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (4.1.1)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (1.3.1)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (0.24.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (0.10.1)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (1.16.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5->plotly_express) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly>=4.1.0->plotly_express) (1.3.3)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->plotly_express) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->plotly_express) (2018.9)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2, random_state = 42)

# Taking pca with 2 components for plotting

pca_x = pca.fit_transform(x)
pca_y = pca.fit_transform(y)
pca_z = pca.fit_transform(z)

# %%
df = pd.DataFrame(Y, columns = ['activity'])
#df.head()
activity = df[['activity']]

# %%
# Creating dataframes for plotting

# %%
pca_x = pd.DataFrame(pca_x, columns = ["pc1", "pc2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
pca_x = pd.concat([pca_x, activity], axis = 1, sort = False)
pca_x = pca_x.sort_values(by='activity')

# %%
pca_y = pd.DataFrame(pca_y, columns = ["pc1", "pc2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
pca_y = pd.concat([pca_y, activity], axis = 1, sort = False)
pca_y = pca_y.sort_values(by='activity')

# %%
pca_z = pd.DataFrame(pca_z, columns = ["pc1", "pc2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
pca_z = pd.concat([pca_z, activity], axis = 1, sort = False)
pca_z = pca_z.sort_values(by='activity')

# %% [markdown]
# ## PCA plot on x axis data

# %%
import plotly_express as px

# plot using plotly express

figx = px.scatter(
    pca_x,
    x="pc1",
    y="pc2",
    color="activity",
    hover_name="activity",
    width=970,
    height=500,
    template="ggplot2",
    color_discrete_sequence=[
        px.colors.qualitative.Vivid[0],
        px.colors.qualitative.Vivid[1],
        px.colors.qualitative.Vivid[2],
        px.colors.qualitative.Vivid[3],
        px.colors.qualitative.Vivid[4],
        px.colors.qualitative.Vivid[5],
    ],
    #facet_col="group_label",
    size_max=0.1,
)

figx.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e3e2564f-bd39-4c07-b924-320ae5bf5921" class="plotly-graph-div" style="height:500px; width:970px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e3e2564f-bd39-4c07-b924-320ae5bf5921")) {
#                     Plotly.newPlot(
#                         'e3e2564f-bd39-4c07-b924-320ae5bf5921',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>activity=Downstairs<br>pc1=%{x}<br>pc2=%{y}", "hovertext": ["Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs"], "legendgroup": "activity=Downstairs", "marker": {"color": "rgb(229, 134, 6)", "symbol": "circle"}, "mode": "markers", "name": "activity=Downstairs", "showlegend": true, "type": "scatter", "x": [-1.707792570435722, 1.5394456273401111, 1.654575190382398, 2.225167055563228, 1.1369461389996123, 1.7654069600030502, 1.577099293342469, 1.7777351451113017, -0.17668558583999344, 1.6278887245322184, 0.7285970338929686, 1.2289748332518071, 1.325434687872494, 1.7916411954977702, 0.8081772273080448, 1.5315669236879434, 1.5917651214089839, 1.306637619724792, 1.426246286817338, 0.09816218301535558, 1.9789743093437757, -0.5762801423784029, 1.4364889315972929, -0.5886939259011708, 2.720155585796987, 0.40928635708839667, 0.8927834103563282, 1.929699844452152, 1.258880752607806, 2.0155113286478197, 1.0143374582602722, 0.8903638265818757, 2.4624679048943894, 1.5832325612252842, 2.4518849433523346, 1.6316576132474971, 1.745527689169503, 2.5031393328225975, 1.7111715289792506, 2.0029148199804245, 1.1072564148359763, 1.4747910056998477, 1.5923208691718675, 1.2259278835572183, 1.3391973958776109, 1.1120986097010879, -3.794329983949705, -3.72195554774143, -4.213859107480184, -4.1387959158592045, -4.570195186153527, -4.083802845740688, -4.741765843145433, -4.928794876108205, -3.5064172724953644, -4.721486965569725, -3.3666274363643622, -4.670686889719134, -3.631266076726235, -3.6648072522662485, -3.229623650838136, -0.8403463426748263, -1.0651381279630396, 0.0873562348437614, 0.2903705529983936, -3.685003055035409, -3.5939381083669493, -1.591743354435231, 0.5297985420219679, -3.1663533523632603, -0.21866998940158605, 0.640654381711977, 0.282463266453082, 1.7677625300612918, -0.13255576944601336, 0.4462293416431069, 1.560335826815359, -0.7846648167806877, 0.9252831613094471, -3.384688016731867, -4.346202773847224, -2.8832079447341004, -3.9055698931423275, -4.470620002620565, -2.6273198448378325, -3.2857455472448445, -4.712503046062456, -3.6072145978359575, -2.8787829330821393], "xaxis": "x", "y": [1.3076742256054912, -3.0137607521426917, -2.345828371120
.0583645340071706, 1.475685027406863, 1.698663746563219, 0.7858044445152249, -0.20420389161275423, -4.451258646609813, -3.470380570528738, -3.7958449647994876, -4.333197350453733, -3.111480842807173, -4.636707710218258, -4.0636154729237255, -3.452163849158839, -3.4964318141648856, -3.124118763265578], "xaxis": "x", "y": [0.6646639296768923, -1.6281781139048397, -1.6678832794798624, -2.3469400417642885, -2.119401714993477, -2.4450098520064065, -0.793694128017524, -0.6277058335350182, 0.07501343727484547, -1.8890990887424006, 0.6363664605293055, 0.06127361324678233, -1.2711740793735407, -1.3702392059785733, -0.7972560176529813, -1.9755316743989364, -1.963876926174755, -2.9228409526406356, -2.9411222863166375, -1.399436366239467, -1.724357090179383, -0.7392195172436636, -1.0493143455629863, 0.5570936408010486, 3.9584552802849062, 1.6483404431216524, -1.6225982503609149, -2.0883960101434482, -1.27928470 ...

# %% [markdown]
# # t-SNE Reduction : (532,80,3) -> (532,3,3)

# %%
# !pip install MulticoreTSNE
# Out:
# Collecting MulticoreTSNE
#   Downloading https://files.pythonhosted.org/packages/2d/e8/2afa896fa4eebfa1d0d0ba2673fddac45582ec0f06b2bdda88108ced5425/MulticoreTSNE-0.1.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from MulticoreTSNE) (1.16.5)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from MulticoreTSNE) (1.13.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->MulticoreTSNE) (2.19)
# Building wheels for collected packages: MulticoreTSNE
#   Building wheel for MulticoreTSNE (setup.py) ... done
#   Created wheel for MulticoreTSNE: filename=MulticoreTSNE-0.1-cp36-cp36m-linux_x86_64.whl size=68507 sha256=69175f6d37977f2797ced52fb0e6c62ea181df093eb0932bc7a9de30acbc4245
#   Stored in directory: /root/.cache/pip/wheels/27/59/53/3b52ee63add3692254c30d687fa4dff4d128d0557861fb028e
# Successfully built MulticoreTSNE
# Installing collected packages: MulticoreTSNE
# Successfully installed MulticoreTSNE-0.1

# %%
#from sklearn.manifold import TSNE
from MulticoreTSNE import MulticoreTSNE as TSNE

# Taking TSNE with 3 components along x,y,z axis seperately

tsne = TSNE(n_components = 5, verbose = 1, perplexity = 30, n_iter = 300)
tsne_x = tsne.fit_transform(x)
tsne_y = tsne.fit_transform(y)
tsne_z = tsne.fit_transform(z)

# %%
# Stack TSNE results from different axes

tsne_stack = np.stack((tsne_x,tsne_y,tsne_z),axis = 2)
tsne_stack.shape
# Out:
# (532, 5, 3)

# %%
tsne_stack
# Out:
# array([[[-0.87478067,  0.28323701,  1.24739628],
#         [ 0.94042148,  4.44848561, -0.12986017],
#         [ 3.00572159, -1.60554202,  1.79583665],
#         [-0.47287004, -6.93099002,  1.75796794],
#         [-7.03603407,  1.7613949 , -0.69332654]],
#
#        [[ 4.5235282 ,  1.53112384, -0.0413038 ],
#         [-2.95786002, -0.94158594, -3.34644864],
#         [ 2.22215576,  7.16907187, -9.0307688 ],
#         [-0.83192852, -3.99853044, -0.69387098],
#         [-4.28900948,  0.57468268,  0.0410538 ]],
#
#        [[ 0.49693765, -0.83946429, -3.23152019],
#         [-6.54053068,  2.73422362,  4.89420383],
#         [ 0.03060336, -1.7143165 ,  2.24934361],
#         [ 0.53747766, -7.20870404, -0.67048932],
#         [-0.05615314, -0.13275072, -5.15000371]],
#
#        ...,
#
#        [[ 6.80199871,  3.16683773, -4.67265782],
#         [-3.80588089,  2.41328345,  4.8945028 ],
#         [-1.08051337,  8.20385033, -0.61671651],
#         [-0.90249255, -1.797436  , -4.230278  ],
#         [-3.1954743 ,  1.12235673, -2.84722009]],
#
#        [[ 6.9098338 ,  3.32894304, -4.58318623],
#         [-3.62325688,  2.37467999,  4.93479087],
#         [-0.96683216,  8.24523703, -0.91073393],
#         [-0.9078372 , -2.00465652, -4.16404762],
#         [-3.06452369,  1.23421704, -3.03931251]],
#
#        [[ 6.87368006,  3.27006069, -4.58612928],
#         [-3.73641999,  2.37188268,  4.80662953],
#         [-1.07450823,  8.13470817, -0.83789502],
#         [-0.83049091, -1.93641703, -4.19965716],
#         [-3.14726664,  1.15173861, -3.0324627 ]]])

# %% [markdown]
# # tSNE Plots

# %% [markdown]
# ## TSNE Plot on x axis data

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components = 2, verbose = 1, perplexity = 4, n_iter = 300)
tsne_x = tsne.fit_transform(x)
tsne_y = tsne.fit_transform(y)
tsne_z = tsne.fit_transform(z)
# Out:
# [t-SNE] Computing 13 nearest neighbors...
# [t-SNE] Indexed 532 samples in 0.003s...
# [t-SNE] Computed neighbors for 532 samples in 0.044s...
# [t-SNE] Computed conditional probabilities for sample 532 / 532
# [t-SNE] Mean sigma: 0.134186
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.233459
# [t-SNE] KL divergence after 300 iterations: 1.718577
# [t-SNE] Computing 13 nearest neighbors...
# [t-SNE] Indexed 532 samples in 0.001s...
# [t-SNE] Computed neighbors for 532 samples in 0.042s...
# [t-SNE] Computed conditional probabilities for sample 532 / 532
# [t-SNE] Mean sigma: 0.133190
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 88.037773
# [t-SNE] KL divergence after 300 iterations: 1.795308
# [t-SNE] Computing 13 nearest neighbors...
# [t-SNE] Indexed 532 samples in 0.001s...
# [t-SNE] Computed neighbors for 532 samples in 0.042s...
# [t-SNE] Computed conditional probabilities for sample 532 / 532
# [t-SNE] Mean sigma: 0.126635
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.662231
# [t-SNE] KL divergence after 300 iterations: 1.649000

# %%
tsne_x = pd.DataFrame(tsne_x, columns = ["tsne1", "tsne2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
tsne_x = pd.concat([tsne_x, activity], axis = 1, sort = False)
tsne_x = tsne_x.sort_values(by='activity')

# %%
tsne_y = pd.DataFrame(tsne_y, columns = ["tsne1", "tsne2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
tsne_y = pd.concat([tsne_y, activity], axis = 1, sort = False)
tsne_y = tsne_y.sort_values(by='activity')

# %%
tsne_z = pd.DataFrame(tsne_z, columns = ["tsne1", "tsne2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
tsne_z = pd.concat([tsne_z, activity], axis = 1, sort = False)
tsne_z = tsne_z.sort_values(by='activity')

# %%
import plotly_express as px

figx = px.scatter(
    tsne_x,
    x="tsne1",
    y="tsne2",
    color="activity",
    hover_name="activity",
    width=970,
    height=500,
    template="ggplot2",
    color_discrete_sequence=[
        px.colors.qualitative.Vivid[0],
        px.colors.qualitative.Vivid[1],
        px.colors.qualitative.Vivid[2],
        px.colors.qualitative.Vivid[3],
        px.colors.qualitative.Vivid[4],
        px.colors.qualitative.Vivid[5],
    ],
    #facet_col="group_label",
    size_max=0.1,
)

figx.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id
# ## TSNE Plot on z axis data

# %%
import plotly_express as px

figz = px.scatter(
    tsne_z,
    x="tsne1",
    y="tsne2",
    color="activity",
    hover_name="activity",
    width=970,
    height=500,
    template="ggplot2",
    color_discrete_sequence=[
        px.colors.qualitative.Vivid[0],
        px.colors.qualitative.Vivid[1],
        px.colors.qualitative.Vivid[2],
        px.colors.qualitative.Vivid[3],
        px.colors.qualitative.Vivid[4],
        px.colors.qualitative.Vivid[5],
    ],
    #facet_col="group_label",
    size_max=0.1,
)

figz.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1372eaf9-2142-459f-95df-4bd40bd70fd5" class="plotly-graph-div" style="height:500px; width:970px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1372eaf9-2142-459f-95df-4bd40bd70fd5")) {
#                     Plotly.newPlot(
#                         '1372eaf9-2142-459f-95df-4bd40bd70fd5',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>activity=Downstairs<br>tsne1=%{x}<br>tsne2=%{y}", "hovertext": ["Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs"], "legendgroup": "activity=Downstairs", "marker": {"color": "rgb(229, 134, 6)", "symbol": "circle"}, "mode": "markers", "name": "activity=Downstairs", "showlegend": true, "type": "scatter", "x": [-0.1958841234445572, 6.498378753662109, 2.6528871059417725, 9.54294490814209, 9.269810676574707, 5.768890857696533, -18.361753463745117, 12.084996223449707, 7.436892986297607, 13.075908660888672, 7.513343811035156, 2.9671597480773926, 11.785768508911133, 31.093935012817383, 35.399696350097656, 31.91914176940918, 5.408959865570068, 4.772745609283447, 27.188404083251953, 9.55189037322998, -12.108973503112793, 9.133810043334961, 7.9802446365356445, 11.199898719787598, -1.4618220329284668, -25.078779220581055, -0.25219160318374634, 8.153326034545898, -0.34384939074516296, 5.836709022521973, 3.7819736003875732, 5.218685626983643, 8.164837837219238, 9.834725379943848, 4.8748674392700195, 2.8979666233062744, 7.1256890296936035, 7.188292980194092, 9.923206329345703, 6.274626731872559, 8.375983238220215, 7.020097255706787, 0.2260744571685791, 8.71540641784668, 26.95970916748047, 4.231075763702393, 37.74630355834961, 11.251319885253906, -12.257383346557617, -1.4339017868041992, -13.669445037841797, 19.065540313720703, -9.88692855834961, -9.682938575744629, -20.538984298706055, -20.45802879333496, -9.242569923400879, -8.752676963806152, 15.802248001098633, 25.2144775390625, -10.554356575012207, -5.81277322769165, -4.871603965759277, 21.08837127685547, 8.32763957977295, -11.040843963623047, -11.01953125, 10.765375137329102, -8.898150444030762, -18.799129486083984, 8.622814178466797, 9.723760604858398, 17.635425567626953, 8.599169731140137, 5.128806114196777, 6.97592306137085, 34.1337776184082, 25.633502960205078, 7.782841205596924, -13.463109970092773, 2.104677438735962, -1.835138201713562, 22.248395919799805, -4.141576290130615, -9.819242477416992, -11.005183219909668, -3.0801291465759277, 14.232295036315918, -7.324006080627441], "xaxis": "x", "y": [3.3128890991210938, -5.251199722290039, -5.660482406616211, -13.12335205078125, -18.690011978149414, -18.364721298217773, 30.715003967285156, -2.35729718208313, -3.1901183128356934, -14.731847763061523, 0.14546889066696167, -3.125882148742676, -9.42345142364502, 7.587484359741211, 19.86327362060547, 26.518186569213867, -8.35460090637207, -19.938011169433594, -14.648459434509277, -18.79219627380371, 29.814739227294922, 0.2410014271736145, -5.378287315368652, -4.379929542541504, -2.027639150619507, -7.084935188293457, -11.776031494140625, -12.909771919250488, -6.401245594024658, -19.80246925354004, -18.22330474853515 ...

# %% [markdown]
# # LDA Reduction (532,80,3) -> (532,3,3)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()
labels = label.fit_transform(Y)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components = 3)
lda_x = lda.fit_transform(x,labels)
lda_y = lda.fit_transform(y,labels)
lda_z = lda.fit_transform(z,labels)

# %%
lda_stack = np.stack((lda_x,lda_y,lda_z),axis = 2)
lda_stack.shape
# Out:
# (532, 3, 3)

# %%
lda_stack
# Out:
# array([[[ 1.97911126,  1.37914844,  1.23009547],
#         [-3.060653  ,  1.23327535,  1.21050449],
#         [-1.57473923, -0.75790765,  1.93668313]],
#
#        [[ 0.49274144,  0.52431717,  2.39718896],
#         [-1.21853003,  0.28130806,  2.4035482 ],
#         [-1.29477303,  0.78813094,  0.29431982]],
#
#        [[ 0.99993278,  2.65156074,  0.34944942],
#         [-0.33887531,  0.10102646,  1.94304237],
#         [ 0.83998888, -1.16773697, -0.8218233 ]],
#
#        ...,
#
#        [[ 1.06144305,  1.3576219 ,  1.22764526],
#         [-0.87850492,  0.63549806,  0.52701934],
#         [ 1.302464  ,  1.36181878, -1.49133966]],
#
#        [[ 1.02171913,  1.39814798,  1.23551715],
#         [-0.92182622,  0.61798663,  0.56745903],
#         [ 1.32974594,  1.33819501, -1.47179942]],
#
#        [[ 1.0074211 ,  1.35542122,  1.18880815],
#         [-0.9456476 ,  0.70538872,  0.55584676],
#         [ 1.35613955,  1.36085401, -1.49677581]]])

# %% [markdown]
# # LDA Plots

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components = 2)
lda_x = lda.fit_transform(x,labels)
lda_y = lda.fit_transform(y,labels)
lda_z = lda.fit_transform(z,labels)

# %%
lda_x = pd.DataFrame(lda_x, columns = ["lda1", "lda2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
lda_x = pd.concat([lda_x, activity], axis = 1, sort = False)
lda_x = lda_x.sort_values(by='activity')

# %%
lda_y = pd.DataFrame(lda_y, columns = ["lda1", "lda2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
lda_y = pd.concat([lda_y, activity], axis = 1, sort = False)
lda_y = lda_y.sort_values(by='activity')

# %%
lda_z = pd.DataFrame(lda_z, columns = ["lda1", "lda2"])
#pca_res = pca_res.sample(n=1000, random_state=42)
lda_z = pd.concat([lda_z, activity], axis = 1, sort = False)
lda_z = lda_z.sort_values(by='activity')

# %% [markdown]
# ## LDA Plot on x axis data

# %%
import plotly_express as px

figx = px.scatter(
    lda_x,
    x="lda1",
    y="lda2",
    color="activity",
    hover_name="activity",
    width=970,
    height=500,
    template="ggplot2",
    color_discrete_sequence=[
        px.colors.qualitative.Vivid[0],
        px.colors.qualitative.Vivid[1],
        px.colors.qualitative.Vivid[2],
        px.colors.qualitative.Vivid[3],
        px.colors.qualitative.Vivid[4],
        px.colors.qualitative.Vivid[5],
    ],
    #facet_col="group_label",
    size_max=0.1,
)

figx.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c38121a2-f486-4f88-9940-5b507a3defd2" class="plotly-graph-div" style="height:500px; width:970px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c38121a2-f486-4f88-9940-5b507a3defd2")) {
#                     Plotly.newPlot(
#                         'c38121a2-f486-4f88-9940-5b507a3defd2',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>activity=Downstairs<br>lda1=%{x}<br>lda2=%{y}", "hovertext": ["Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs"], "legendgroup": "activity=Downstairs", "marker": {"color": "rgb(229, 134, 6)", "symbol": "circle"}, "mode": "markers", "name": "activity=Downstairs", "showlegend": true, "type": "scatter", "x": [-1.1192188248192467, 0.5344535196698019, 0.29370356381834306, 0.8893775562072965, 0.6574813949498476, 1.7026230757772187, 0.056300300240242185, 0.25751668188952886, -1.3813802599160565, 0.6309231621104056, -0.07778905837717377, 0.21330182244873927, 0.5906849046348948, -0.4148934754721333, 0.7126016969174778, 0.9371503463154217, 0.6571393421301571, -0.04264714991659235, 0.07989456382428634, -0.619388550442439, 0.6058420820954205, 0.48112939694281703, -0.07454503086510603, -0.5210963533739846, -3.7036503097344693, -0.8778438522274159, 0.8469886975349571, 0.2759802233261554, 0.985460028057006, 1.577064482754169, 0.09183804430095638, 0.6468282934384805, 0.8175854671277617, 1.2319001141374069, 1.529823391802763, 0.441734942238691, 1.2130865219658513, 1.704292835590398, 1.2878879264753018, -0.9571357285242497, -0.3522458284960136, -0.5330183730328065, 1.3213573486133778, -0.07831272170056527, 0.7392051720761955, -0.11778021256763258, -1.5113699407236358, -1.2990318384955049, -1.1748879239705539, -2.0130208492480035, -1.39863984856854, -1.7348720374162419, -1.5882650365724496, -1.7886112081456207, -2.0317471715667543, -2.3624583953321574, -1.5724302070346428, -1.0668469561937883, -2.5203532297971107, -1.7541268978819398, -1.6461178562093717, -2.0961871538288777, -1.3242420398175248, -0.5127271423010443, -0.330578107877835, -1.657540485089681, -0.5230284178844737, -0.045958752273046376, -0.9894505694133005, -1.6866191714161498, -0.22530489283424637, 0.765970302471841, -0.039237684222178604, 0.2245867796040592, 0.4709243404818644, -0.013957154489837167, -0.01167424413390812, -0.9773016051136567, 0.809840087481555, -1.723709536663615, -1.781548881527988, -2.1779676248307576, -1.9563663408341707, -2.652032309095781, -1.855377421245259, -0.8199858569195072, -0.7294690855696206, -2.467511803606034, -1.0404809879305403], "xaxis": "x", "y": [0.7558695241451212, -1.9457582584627446, -1.5539131781589495, -0.7158507864187019, -0.948608188454328, 2.3152418172928417, 0.581831946450424, -0.42367071847357507, 0.09488722536640609, 0.22224328848493766, -0.7469384939945003, -0.34037848056298725, -0.8776568171260576, -1.6225594533924863, 0.8264867936582405, -1.4344261875810982, -0.6521177444941001, -0.7320073248030478, 1.8266013223033777, -0.10351918500909418, -0.6913829392445254, 0.24994131052990837, -1.7062530793782633, 1.8051481188400715, -0.3641233273447061, -1.80603370243 ...

# %% [markdown]
# ## LDA Plot on y axis data

# %%
import plotly_express as px

figy = px.scatter(
    lda_y,
    x="lda1",
    y="lda2",
    color="activity",
    hover_name="activity",
    width=970,
    height=500,
    template="ggplot2",
    color_discrete_sequence=[
        px.colors.qualitative.Vivid[0],
        px.colors.qualitative.Vivid[1],
        px.colors.qualitative.Vivid[2],
        px.colors.qualitative.Vivid[3],
        px.colors.qualitative.Vivid[4],
        px.colors.qualitative.Vivid[5],
    ],
    #facet_col="group_label",
    size_max=0.1,
)

figy.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="be478b02-f487-4f18-91b9-d0cb31a7d5da" class="plotly-graph-div" style="height:500px; width:970px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("be478b02-f487-4f18-91b9-d0cb31a7d5da")) {
#                     Plotly.newPlot(
#                         'be478b02-f487-4f18-91b9-d0cb31a7d5da',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>activity=Downstairs<br>lda1=%{x}<br>lda2=%{y}", "hovertext": ["Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs", "Downstairs"], "legendgroup": "activity=Downstairs", "marker": {"color": "rgb(229, 134, 6)", "symbol": "circle"}, "mode": "markers", "name": "activity=Downstairs", "showlegend": true, "type": "scatter", "x": [-2.2796648327197158, -0.6555407604439364, 0.412438634194175, -1.2182670868359187, 0.8123978918135736, 0.3987416855898122, 0.37638519063894454, -0.7919068568088687, 0.3242626514169155, 0.13607721409918944, 0.252275181031965, 0.3183647513930756, 0.8132474728364678, -0.37906857128682336, -0.18507876385836855, -0.9022139064235687, -0.0926465609169444, -0.3143134665708509, 1.5147248931993642, 0.6917466689907771, -0.3215526400341552, 1.0565571033838965, -0.11193344561889093, 0.2616126099843418, -2.565925573398545, -0.5780926215547157, 0.3011145058415536, 0.6292713747847153, 1.8830254523291914, 0.8019171568637956, 1.6163658671397576, 1.0718834119348766, -0.36201524862291434, 1.388796932871395, 1.2216659921753983, 1.3344177708452412, 1.7696925619918977, 0.706060740889858, 0.1826739090924976, 0.3462247507653511, -0.09197526551518827, 0.23184025064650945, 0.022648529854054963, -1.019859909613625, 1.2076503449382385, -0.2602087453398382, -1.8548555382255847, -1.5728335164031924, -2.235268410996001, -2.1288857046029572, -1.728773436785674, -1.7487800826874775, -1.7400779060016074, -2.124889303453854, -1.9656247934038706, -2.326644540546247, -0.9384822261224388, -2.084924087039728, -1.9426642620842838, -1.8524800337915928, -2.2774134696815054, -1.363609308188042, -1.1671700925809094, -1.3158055188650761, -0.4679415128592097, -1.0742693172606261, -0.9800445782621554, -0.24765332715703695, -0.3711587287467329, -2.5957148072709613, 0.042436961247172805, 0.03126795880237445, 0.12340569990830966, 0.6038996354865572, 1.9797779529075525, 0.7523566328101026, -0.4670955340547873, 0.7454791276895412, -0.6222425815741727, -1.163198340804762, -1.754909970302268, -2.1352429491303857, -2.590220123670598, -2.0821879438872957, -1.1821954251650781, -1.9625142030000575, -1.4467185843031911, -1.7217819766212707, -1.7424562456739936], "xaxis": "x", "y": [-0.0040633979677001525, 0.572944344280503, -0.37622741339329724, -0.18678244456262075, 0.9136497130256701, 0.2669895698948583, 0.7059090635903658, 1.6623162382548318, 1.139755471893065, 1.367224763464664, -0.42070412808369145, 1.198565228383978, 1.8894130665873796, -1.5961770419629808, 1.4566970167544557, -0.23851035012926133, -0.7559836301157261, 0.9835107054482869, 1.3257774125559523, 0.2962709628868077, -1.4016942494665927, 0.7954447380631653, -1.583202843595196, 0.2834189602562281, -0.9146475047936512, 0.44448207939261986, 0.9174 ...

# %% [markdown]
# ## LDA Plot on z axis data

# %%
import plotly_express as px

figz = px.scatter(
    lda_z,
    x="lda1",
    y="lda2",
    color="activity",
    hover_name="activity",
    width=970,
    height=500,
    template="ggplot2",
    color_discrete_sequence=[
        px.colors.qualitative.Vivid[0],
        px.colors.qualitative.Vivid[1],
        px.colors.qualitative.Vivid[2],
        px.colors.qualitative.Vivid[3],
        px.colors.qualitative.Vivid[4],
        px.colors.qualitative.Vivid[5],
    ],
    #facet_col="group_label",
    size_max=0.1,
)

figz.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="